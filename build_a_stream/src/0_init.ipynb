# %%
# %md
# Stream Pipeline Initialization

This notebook initializes the parameters and environment required for building a streaming data pipeline.  
It sets up the catalog, schema, and volume in Databricks, and prepares the necessary output and checkpoint paths for streaming data.

**Steps included:**
- Import required modules and parameters
- Set up catalog, schema, and volume
- Define output and checkpoint locations
# Out:
# # Stream Pipeline Initialization
#
# This notebook initializes the parameters and environment required for building a streaming data pipeline.
# It sets up the catalog, schema, and volume in Databricks, and prepares the necessary output and checkpoint paths for streaming data.
#
# **Steps included:**
# - Import required modules and parameters
# - Set up catalog, schema, and volume
# - Define output and checkpoint locations

# %%
from build_a_stream.stream_builder import *

# %%
params
# Out:
# Params(catalog=None, schema=None, volume='stream', updated_at='2025-06-27 11:29:10')

# %%
catalog = params.catalog
schema = params.schema
volume_name = params.volume

# %%
print(catalog, schema, volume_name)
# Out:
# None None stream

# %%
transaction_output = f"/Volumes/{catalog}/{schema}/{volume_name}/stream_data/source_transactions"
dimension_output =  f"/Volumes/{catalog}/{schema}/{volume_name}/stream_data/source_dimensions"
checkpoint = f"/Volumes/{catalog}/{schema}/{volume_name}/stream_metadata/checkpoint"

# %%
spark.sql(f"CREATE CATALOG IF NOT EXISTS {catalog}")
spark.sql(f"USE CATALOG {catalog}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {schema}")
spark.sql(f"USE SCHEMA {schema}")
spark.sql(f"CREATE VOLUME IF NOT EXISTS {volume_name} COMMENT 'This is the landing data for buildastream mock data'")
# Out:
# DataFrame[]
