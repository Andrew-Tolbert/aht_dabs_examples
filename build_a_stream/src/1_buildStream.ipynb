# %%
catalog = dbutils.widgets.get("Catalog")
schema = dbutils.widgets.get("Schema")
total_rows_m = float(dbutils.widgets.get("Total_Records_M"))
stream_length_m = float(dbutils.widgets.get("Total_Stream_Length_m"))
files_per_m = int(dbutils.widgets.get("Files_per_min"))
reset_data = True if dbutils.widgets.get("Reset_Data") == 'Y' else False 
compression = True if dbutils.widgets.get("Compression") == 'Y' else False 
streaming_mode = True if dbutils.widgets.get("Streaming_Mode") == 'Y' else False
